# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet('part-00000-3681c0a2-ae63-465f-8d2e-a972a100efca.c000.snappy (1).parquet')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868000 entries, 0 to 867999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   price              868000 non-null  float64
#  1   size               868000 non-null  float64
#  2   exchange_index     868000 non-null  float64
#  3   tape_index         868000 non-null  float64
#  4   condition_at       868000 non-null  int32
#  5   condition_i        868000 non-null  int32
#  6   condition_t        868000 non-null  int32
#  7   hour               868000 non-null  int32
#  8   minute             868000 non-null  int32
#  9   second             868000 non-null  int32
#  10  day_of_week        868000 non-null  int32
#  11  timestamp_epoch    868000 non-null  int64
#  12  rolling_avg_price  868000 non-null  float64
#  13  rolling_std_price  867999 non-null  float64
#  14  cumulative_volume  868000 non-null  float64
# ...

# %%
df.head()
# Out:
#     price   size  exchange_index  tape_index  condition_at  condition_i  \
# 0  202.97   20.0             1.0         0.0             1            1
# 1  202.97   20.0             1.0         0.0             1            1
# 2  202.97   20.0             1.0         0.0             1            1
# 3  202.97  161.0             1.0         0.0             1            0
# 4  202.97  161.0             1.0         0.0             1            0
#
#    condition_t  hour  minute  second  day_of_week  timestamp_epoch  \
# 0            1    13      30       0            4       1749043800
# 1            1    13      30       0            4       1749043800
# 2            1    13      30       0            4       1749043800
# 3            1    13      30       0            4       1749043800
# 4            1    13      30       0            4       1749043800
#
#    rolling_avg_price  rolling_std_price  cumulative_volume
# 0             202.97                NaN               20.0
# ...

# %%
df['rolling_avg_price'].value_counts()
# Out:
# rolling_avg_price
# 203.000000    30016
# 205.000000     5868
# 202.950000     4121
# 202.980000     4106
# 202.970000     3990
#               ...
# 205.037709        1
# 205.040418        1
# 205.040009        1
# 205.039600        1
# 205.038782        1
# Name: count, Length: 214090, dtype: int64

# %%
df.to_json("market_transform01_appl.json", orient="records", lines=True)
